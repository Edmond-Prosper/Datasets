# %% [markdown]
# # ANALYSE DES DONNEES RECUES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Importation des fichiers

# %% [markdown]
# ##### Fichiers profondeur de 10 centimetres

# %%
file_dir_p10_d0 = '../Profond 10 cm/distance 0 m/dataset_recv.csv'
file_dir_p10_d15 = '../Profond 10 cm/distance 15 m/dataset_recv.csv'
file_dir_p10_d30 = '../Profond 10 cm/distance 30 m/dataset_recv.csv'
file_dir_p10_d45 = '../Profond 10 cm/distance 45 m/dataset_recv.csv'
file_dir_p10_d45obs = '../Profond 10 cm/Obstacle/45m 1mur/dataset_recv.csv'
file_dir_p10_d60 = '../Profond 10 cm/distance 60 m/dataset_recv.csv'

col_names = ['date','id', 'ambit_humidity', 'temperature', 'soil_moisture', 'transmited_power', 'sf', 'rx_timestamp', 'rssi', 'snr', 'sfrx', 'sftx', 'tx_trials', 'tx_power', 'tx_time_on_air', 'tx_counter', 'tx_frequency']

df_p10_d0 = pd.read_csv(file_dir_p10_d0, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p10_d15 = pd.read_csv(file_dir_p10_d15, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p10_d30 = pd.read_csv(file_dir_p10_d30, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p10_d45 = pd.read_csv(file_dir_p10_d45, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p10_d45obs = pd.read_csv(file_dir_p10_d45obs, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p10_d60 = pd.read_csv(file_dir_p10_d60, sep=';', header=None, usecols=range(len(col_names)), names=col_names)

# %% [markdown]
# ##### Fichiers profondeur de 20 centimetres

# %%
file_dir_p20_d0 = '../Profond 20 cm/distance 0 m/dataset_recv.csv'
file_dir_p20_d15 = '../Profond 20 cm/distance 15 m/dataset_recv.csv'
file_dir_p20_d30 = '../Profond 20 cm/distance 30 m/dataset_recv.csv'
file_dir_p20_d45 = '../Profond 20 cm/distance 45 m/dataset_recv.csv'
file_dir_p20_d45obs = '../Profond 20 cm/Obstacle/45m 1mur/dataset_recv.csv'
file_dir_p20_d60 = '../Profond 20 cm/distance 60 m/dataset_recv.csv'

col_names = ['date','id', 'ambit_humidity', 'temperature', 'soil_moisture', 'transmited_power', 'sf', 'rx_timestamp', 'rssi', 'snr', 'sfrx', 'sftx', 'tx_trials', 'tx_power', 'tx_time_on_air', 'tx_counter', 'tx_frequency']

df_p20_d0 = pd.read_csv(file_dir_p20_d0, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p20_d15 = pd.read_csv(file_dir_p20_d15, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p20_d30 = pd.read_csv(file_dir_p20_d30, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p20_d45 = pd.read_csv(file_dir_p20_d45, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p20_d45obs = pd.read_csv(file_dir_p20_d45obs, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p20_d60 = pd.read_csv(file_dir_p20_d60, sep=';', header=None, usecols=range(len(col_names)), names=col_names)

# %% [markdown]
# ##### Fichiers profondeur de 30 centimetres

# %%
file_dir_p30_d0 = '../Profond 30 cm/distance 0 m/dataset_recv.csv'
file_dir_p30_d15 = '../Profond 30 cm/distance 15 m/dataset_recv.csv'
file_dir_p30_d30 = '../Profond 30 cm/distance 30 m/dataset_recv.csv'
file_dir_p30_d45 = '../Profond 30 cm/distance 45 m/dataset_recv.csv'
file_dir_p30_d45obs = '../Profond 30 cm/Obstacle/45m 1mur/dataset_recv.csv'
file_dir_p30_d60 = '../Profond 30 cm/distance 60 m/dataset_recv.csv'

col_names = ['date','id', 'ambit_humidity', 'temperature', 'soil_moisture', 'transmited_power', 'sf', 'rx_timestamp', 'rssi', 'snr', 'sfrx', 'sftx', 'tx_trials', 'tx_power', 'tx_time_on_air', 'tx_counter', 'tx_frequency']

df_p30_d0 = pd.read_csv(file_dir_p30_d0, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p30_d15 = pd.read_csv(file_dir_p30_d15, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p30_d30 = pd.read_csv(file_dir_p30_d30, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p30_d45 = pd.read_csv(file_dir_p30_d45, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p30_d45obs = pd.read_csv(file_dir_p30_d45obs, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p30_d60 = pd.read_csv(file_dir_p30_d60, sep=';', header=None, usecols=range(len(col_names)), names=col_names)

# %% [markdown]
# ##### Fichiers profondeur de 40 centimetres

# %%
file_dir_p40_d0 = '../Profond 40 cm/distance 0 m/dataset_recv.csv'
file_dir_p40_d15 = '../Profond 40 cm/distance 15 m/dataset_recv.csv'
file_dir_p40_d30 = '../Profond 40 cm/distance 30 m/dataset_recv.csv'
file_dir_p40_d45 = '../Profond 40 cm/distance 45 m/dataset_recv.csv'
file_dir_p40_d45obs = '../Profond 40 cm/Obstacle/45m 1mur/dataset_recv.csv'
file_dir_p40_d60 = '../Profond 40 cm/distance 60 m/dataset_recv.csv'

col_names = ['date','id', 'ambit_humidity', 'temperature', 'soil_moisture', 'transmited_power', 'sf', 'rx_timestamp', 'rssi', 'snr', 'sfrx', 'sftx', 'tx_trials', 'tx_power', 'tx_time_on_air', 'tx_counter', 'tx_frequency']

df_p40_d0 = pd.read_csv(file_dir_p40_d0, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p40_d15 = pd.read_csv(file_dir_p40_d15, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p40_d30 = pd.read_csv(file_dir_p40_d30, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p40_d45 = pd.read_csv(file_dir_p40_d45, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p40_d45obs = pd.read_csv(file_dir_p40_d45obs, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p40_d60 = pd.read_csv(file_dir_p40_d60, sep=';', header=None, usecols=range(len(col_names)), names=col_names)

# %% [markdown]
# ##### Fichiers profondeur de 50 centimetres

# %%
file_dir_p50_d0 = '../Profond 50 cm/distance 0 m/dataset_recv.csv'
file_dir_p50_d15 = '../Profond 50 cm/distance 15 m/dataset_recv.csv'
file_dir_p50_d30 = '../Profond 50 cm/distance 30 m/dataset_recv.csv'
file_dir_p50_d45 = '../Profond 50 cm/distance 45 m/dataset_recv.csv'
file_dir_p50_d45obs = '../Profond 50 cm/Obstacle/45m 1mur/dataset_recv.csv'
file_dir_p50_d60 = '../Profond 50 cm/distance 60 m/dataset_recv.csv'

col_names = ['date','id', 'ambit_humidity', 'temperature', 'soil_moisture', 'transmited_power', 'sf', 'rx_timestamp', 'rssi', 'snr', 'sfrx', 'sftx', 'tx_trials', 'tx_power', 'tx_time_on_air', 'tx_counter', 'tx_frequency']

df_p50_d0 = pd.read_csv(file_dir_p50_d0, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p50_d15 = pd.read_csv(file_dir_p50_d15, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p50_d30 = pd.read_csv(file_dir_p50_d30, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p50_d45 = pd.read_csv(file_dir_p50_d45, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p50_d45obs = pd.read_csv(file_dir_p50_d45obs, sep=';', header=None, usecols=range(len(col_names)), names=col_names)
df_p50_d60 = pd.read_csv(file_dir_p50_d60, sep=';', header=None, usecols=range(len(col_names)), names=col_names)

# %%
file_dir_p10 = '../Profond 10 cm/Émetteur/dataset_send.csv'
file_dir_p20 = '../Profond 20 cm/Émetteur/dataset_send.csv'
file_dir_p30 = '../Profond 30 cm/Émetteur/dataset_send.csv'
file_dir_p40 = '../Profond 40 cm/Émetteur/dataset_send.csv'
file_dir_p50 = '../Profond 50 cm/Émetteur/dataset_send.csv'

send_col_names = ['id', 'ambit_humidity', 'temperature', 'soil_moisture', 'transmited_power', 'sf', 'rx_timestamp', 'rssi', 'snr', 'sfrx', 'sftx', 'tx_trials', 'tx_power', 'tx_time_on_air', 'tx_counter', 'tx_frequency']

df_send_p10 = pd.read_csv(file_dir_p10, sep=';', header=None, usecols=range(len(send_col_names)), names=send_col_names)
df_send_p20 = pd.read_csv(file_dir_p20, sep=';', header=None, usecols=range(len(send_col_names)), names=send_col_names)
df_send_p30 = pd.read_csv(file_dir_p30, sep=';', header=None, usecols=range(len(send_col_names)), names=send_col_names)
df_send_p40 = pd.read_csv(file_dir_p40, sep=';', header=None, usecols=range(len(send_col_names)), names=send_col_names)
df_send_p50 = pd.read_csv(file_dir_p50, sep=';', header=None, usecols=range(len(send_col_names)), names=send_col_names)

# %%
df_send_p10.head()
# Out:
#    id ambit_humidity temperature soil_moisture transmited_power     sf  \
# 0   1           H=79        T=34        Hs=0.0             sp=2   sf=7
# 1   2           H=79        T=34        Hs=0.0             sp=2  sf=12
# 2   3           H=79        T=34        Hs=0.0            sp=20   sf=7
# 3   4           H=79        T=34        Hs=0.0            sp=20  sf=12
# 4   5           H=69        T=34        Hs=0.0             sp=2   sf=7
#
#      rx_timestamp     rssi       snr     sfrx      sftx     tx_trials  \
# 0  rx_timestamp=0   rssi=0   snr=0.0   sfrx=0    sftx=7   tx_trials=0
# 1  rx_timestamp=0   rssi=0   snr=0.0   sfrx=0   sftx=12   tx_trials=0
# 2  rx_timestamp=0   rssi=0   snr=0.0   sfrx=0    sftx=7   tx_trials=0
# 3  rx_timestamp=0   rssi=0   snr=0.0   sfrx=0   sftx=12   tx_trials=0
# 4  rx_timestamp=0   rssi=0   snr=0.0   sfrx=0    sftx=7   tx_trials=0
#
#        tx_power        tx_time_on_air     tx_counter             tx_frequency
# ...

# %%
df_send_p10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1773 entries, 0 to 1772
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1773 non-null   int64
#  1   ambit_humidity    1773 non-null   object
#  2   temperature       1773 non-null   object
#  3   soil_moisture     1773 non-null   object
#  4   transmited_power  1773 non-null   object
#  5   sf                1773 non-null   object
#  6   rx_timestamp      1773 non-null   object
#  7   rssi              1773 non-null   object
#  8   snr               1773 non-null   object
#  9   sfrx              1773 non-null   object
#  10  sftx              1773 non-null   object
#  11  tx_trials         1773 non-null   object
#  12  tx_power          1773 non-null   object
#  13  tx_time_on_air    1773 non-null   object
#  14  tx_counter        1773 non-null   object
#  15  tx_frequency      1773 non-null   object
# ...

# %%
df_p50_d45.head()
# Out:
#    date   id ambit_humidity temperature soil_moisture transmited_power     sf  \
# 0  0000  491           H=37        T=41   Hs=60.77663            sp=20   sf=7
# 1  0000  492           H=37        T=41   Hs=60.77663            sp=20  sf=12
# 2  0000  493           H=35        T=41   Hs=60.84788             sp=2   sf=7
# 3  0000  494           H=35        T=41   Hs=60.84788             sp=2  sf=12
# 4  0000  495           H=35        T=41   Hs=60.84788            sp=20   sf=7
#
#             rx_timestamp        rssi        snr      sfrx     sftx  \
# 0  rx_timestamp=10121149    rssi=-95    snr=6.0    sfrx=7   sftx=0
# 1  rx_timestamp=33160230    rssi=-95    snr=6.0   sfrx=12   sftx=0
# 2  rx_timestamp=53416261   rssi=-111   snr=-6.0    sfrx=7   sftx=0
# 3  rx_timestamp=76455316   rssi=-109   snr=-1.0   sfrx=12   sftx=0
# 4  rx_timestamp=95648405    rssi=-98    snr=5.0    sfrx=7   sftx=0
#
#       tx_trials      tx_power     tx_time_on_air     tx_counter  \
# ...

# %%
df_p50_d45.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              206 non-null    object
#  1   id                206 non-null    int64
#  2   ambit_humidity    206 non-null    object
#  3   temperature       206 non-null    object
#  4   soil_moisture     206 non-null    object
#  5   transmited_power  206 non-null    object
#  6   sf                206 non-null    object
#  7   rx_timestamp      206 non-null    object
#  8   rssi              206 non-null    object
#  9   snr               206 non-null    object
#  10  sfrx              206 non-null    object
#  11  sftx              206 non-null    object
#  12  tx_trials         206 non-null    object
#  13  tx_power          206 non-null    object
#  14  tx_time_on_air    206 non-null    object
#  15  tx_counter        206 non-null    object
# ...

# %%
df = [
        [
            (df_p10_d0, 'Profondeur: 10; Distance: 0m'),
            (df_p10_d15,  'Profondeur: 10; Distance: 15m'),
            (df_p10_d30,  'Profondeur: 10; Distance: 30m'),
            (df_p10_d45,  'Profondeur: 10; Distance: 45m'),
            (df_p10_d45obs, 'Profondeur: 10; Distance: 45m obs'),
            (df_p10_d60, 'Profondeur: 10; Distance: 60m'),
        ],

        [
            (df_p20_d0, 'Profondeur: 20; Distance: 0m'),
            (df_p20_d15,  'Profondeur: 20; Distance: 15m'),
            (df_p20_d30,  'Profondeur: 20; Distance: 30m'),
            (df_p20_d45,  'Profondeur: 20; Distance: 45m'),
            (df_p20_d45obs, 'Profondeur: 20; Distance: 45m obs'),
            (df_p20_d60, 'Profondeur: 20; Distance: 60m'),
        ],

        [
            (df_p30_d0, 'Profondeur: 30; Distance: 0m'),
            (df_p30_d15,  'Profondeur: 30; Distance: 15m'),
            (df_p30_d30,  'Profondeur: 30; Distance: 30m'),
            (df_p30_d45,  'Profondeur: 30; Distance: 45m'),
            (df_p30_d45obs, 'Profondeur: 30; Distance: 45m obs'),
            (df_p30_d60, 'Profondeur: 30; Distance: 60m'),
        ],

        [
            (df_p40_d0, 'Profondeur: 40; Distance: 0m'),
            (df_p40_d15,  'Profondeur: 40; Distance: 15m'),
            (df_p40_d30,  'Profondeur: 40; Distance: 30m'),
            (df_p40_d45,  'Profondeur: 40; Distance: 45m'),
            (df_p40_d45obs, 'Profondeur: 40; Distance: 45m obs'),
            (df_p40_d60, 'Profondeur: 40; Distance: 60m'),
        ],

        [
            (df_p50_d0, 'Profondeur: 50; Distance: 0m'),
            (df_p50_d15,  'Profondeur: 50; Distance: 15m'),
            (df_p50_d30,  'Profondeur: 50; Distance: 30m'),
            (df_p50_d45,  'Profondeur: 50; Distance: 45m'),
            (df_p50_d45obs, 'Profondeur: 50; Distance: 45m obs'),
            (df_p50_d60, 'Profondeur: 50; Distance: 60m'),
        ]
]

# %%
df_send = [df_send_p10, df_send_p20, df_send_p30, df_send_p40, df_send_p50]

# %% [markdown]
# #### Nettoyage des données
# Afin d'avoir uniquement des valeurs dans les cellules

# %%
def clean_data(df):
    
    df['ambit_humidity'] = np.int64(df['ambit_humidity'].apply(lambda x: str.replace(x, 'H=', '')))

    df['temperature'] = np.int64(df['temperature'].apply(lambda x: str.replace(x, 'T=', '')))

    df['soil_moisture'] = np.float64(df['soil_moisture'].apply(lambda x: str.replace(x, 'Hs=', '')))

    df['transmited_power'] = np.int64(df['transmited_power'].apply(lambda x: str.replace(x, 'sp=', '')))

    df['sf'] = np.int64(df['sf'].apply(lambda x: str.replace(x, 'sf=', '')))

    df['rx_timestamp'] = np.int64(df['rx_timestamp'].apply(lambda x: str.replace(x, 'rx_timestamp=', '')))

    df['rssi'] = np.int64(df['rssi'].apply(lambda x: str.replace(x, 'rssi=', '')))

    df['snr'] = np.float64(df['snr'].apply(lambda x: str.replace(x, 'snr=', '')))

    df['sfrx'] = np.int64(df['sfrx'].apply(lambda x: str.replace(x, 'sfrx=', '')))

    df['sftx'] = np.int64(df['sftx'].apply(lambda x: str.replace(x, 'sftx=', '')))

    df['tx_trials'] = np.int64(df['tx_trials'].apply(lambda x: str.replace(x, 'tx_trials=', '')))

    df['tx_power'] = np.int64(df['tx_power'].apply(lambda x: str.replace(x, 'tx_power=', '')))

    df['tx_time_on_air'] = np.int64(df['tx_time_on_air'].apply(lambda x: str.replace(x, 'tx_time_on_air=', '')))

    df['tx_counter'] = np.int64(df['tx_counter'].apply(lambda x: str.replace(x, 'tx_counter=', '')))

    df['tx_frequency'] = np.int64(df['tx_frequency'].apply(lambda x: str.replace(x, 'tx_frequency=', '')))

    return df

# %% [markdown]
# #### get_index_from_packet_id(): function that return the dataframe index according to a given packet id

# %%
def idp(df, id): # alias of get_index_from_packet_id()
    result = df['id'] == id
    for i in range(0, len(result)):
        if result[i] == True:
            return i
        
    return -1

# %%
def lost_packet(df_send, df_recv, id_debut, id_fin):
    id_send_begin = idp(df_send, id_debut)
    id_recv_begin = idp(df_recv, id_debut)
    id_send_end = idp(df_send, id_fin)
    id_recv_end = idp(df_recv, id_fin)

    nb_send_packet = id_send_end - id_send_begin + 1 # + 1 because id begin at 0
    nb_recv_packet = id_recv_end - id_recv_begin + 1
    nb_lost_packet = nb_send_packet - nb_recv_packet

    print('Nombre de packet envoye : {}'.format(nb_send_packet))
    print('Nombre de packet recu : {}'.format(nb_recv_packet))
    print('Nombre de packet perdu : {}'.format(nb_lost_packet))

    return nb_lost_packet

# %%
def pid(df, index): # alias of get_index_from_packet_id()
    return df['id'][index]

# %%
for set_elt in df:
    for elt in set_elt:
        elt = clean_data(elt[0])


for elt in df_send:
    elt = clean_data(elt)

# %%
print(df_p10_d0.shape)
print(df_send_p10.shape)
# Out:
# (281, 17)
# (1773, 16)

# %%
df_send_p10.head()
# Out:
#    id  ambit_humidity  temperature  soil_moisture  transmited_power  sf  \
# 0   1              79           34            0.0                 2   7
# 1   2              79           34            0.0                 2  12
# 2   3              79           34            0.0                20   7
# 3   4              79           34            0.0                20  12
# 4   5              69           34            0.0                 2   7
#
#    rx_timestamp  rssi  snr  sfrx  sftx  tx_trials  tx_power  tx_time_on_air  \
# 0             0     0  0.0     0     7          0         2              67
# 1             0     0  0.0     0    12          0         2            1647
# 2             0     0  0.0     0     7          0        20              67
# 3             0     0  0.0     0    12          0        20            1647
# 4             0     0  0.0     0     7          0         2              67
#
#    tx_counter  tx_frequency
# 0           1     868000000
# ...

# %%
df_p10_d0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281 entries, 0 to 280
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              281 non-null    object
#  1   id                281 non-null    int64
#  2   ambit_humidity    281 non-null    int64
#  3   temperature       281 non-null    int64
#  4   soil_moisture     281 non-null    float64
#  5   transmited_power  281 non-null    int64
#  6   sf                281 non-null    int64
#  7   rx_timestamp      281 non-null    int64
#  8   rssi              281 non-null    int64
#  9   snr               281 non-null    float64
#  10  sfrx              281 non-null    int64
#  11  sftx              281 non-null    int64
#  12  tx_trials         281 non-null    int64
#  13  tx_power          281 non-null    int64
#  14  tx_time_on_air    281 non-null    int64
#  15  tx_counter        281 non-null    int64
# ...

# %% [markdown]
# #### Desciption des donnees

# %%
df[1][4][0].describe()
# Out:
#                id  ambit_humidity  temperature  soil_moisture  \
# count  197.000000      197.000000   197.000000     197.000000
# mean   359.639594       36.746193    40.304569      24.938922
# std     58.109389        4.456885     2.436673       0.495553
# min    259.000000       29.000000    34.000000      23.904530
# 25%    310.000000       33.000000    40.000000      24.474530
# 50%    359.000000       37.000000    40.000000      24.902030
# 75%    410.000000       39.000000    42.000000      25.293910
# max    459.000000       50.000000    44.000000      25.863910
#
#        transmited_power          sf  rx_timestamp        rssi         snr  \
# count        197.000000  197.000000  1.970000e+02  197.000000  197.000000
# mean          10.862944    9.487310  2.150938e+09 -102.502538    4.126904
# std            9.021884    2.506337  1.253581e+09    7.402168    2.674356
# min            2.000000    7.000000  4.673221e+06 -114.000000   -3.000000
# ...

# %% [markdown]
# ### Visualisation des parametres reseaux

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
print(idp(df_p10_d45, 244))
print(idp(df_p10_d45, 665))
# Out:
# 174
# -1

# %% [markdown]
# #### col_names = ['date','id', 'ambit_humidity', 'temperature', 'soil_moisture', 'transmited_power', 'sf', 'rx_timestamp', 'rssi', 'snr', 'sfrx', 'sftx', 'tx_trials', 'tx_power', 'tx_time_on_air', 'tx_counter', 'tx_frequency']

# %%
df_p40_d45_sf7_pw2 = df_p40_d45[df_p40_d45['sf'] == 7][df_p40_d45['transmited_power'] == 2]
df_p40_d45_sf7_pw20 = df_p40_d45[df_p40_d45['sf'] == 7][df_p40_d45['transmited_power'] == 20]
df_p40_d45_sf12_pw2 = df_p40_d45[df_p40_d45['sf'] == 12][df_p40_d45['transmited_power'] == 2]
df_p40_d45_sf12_pw20 = df_p40_d45[df_p40_d45['sf'] == 12][df_p40_d45['transmited_power'] == 20]

df_p40_d45obs_sf7_pw2 = df_p40_d45obs[df_p40_d45obs['sf'] == 7][df_p40_d45obs['transmited_power'] == 2]
df_p40_d45obs_sf7_pw20 = df_p40_d45obs[df_p40_d45obs['sf'] == 7][df_p40_d45obs['transmited_power'] == 20]
df_p40_d45obs_sf12_pw2 = df_p40_d45obs[df_p40_d45obs['sf'] == 12][df_p40_d45obs['transmited_power'] == 2]
df_p40_d45obs_sf12_pw20 = df_p40_d45obs[df_p40_d45obs['sf'] == 12][df_p40_d45obs['transmited_power'] == 20]
# Out:
# C:\Users\Prosper\AppData\Local\Temp\ipykernel_10816\2930265805.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_p40_d45_sf7_pw2 = df_p40_d45[df_p40_d45['sf'] == 7][df_p40_d45['transmited_power'] == 2]
# C:\Users\Prosper\AppData\Local\Temp\ipykernel_10816\2930265805.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_p40_d45_sf7_pw20 = df_p40_d45[df_p40_d45['sf'] == 7][df_p40_d45['transmited_power'] == 20]
# C:\Users\Prosper\AppData\Local\Temp\ipykernel_10816\2930265805.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_p40_d45_sf12_pw2 = df_p40_d45[df_p40_d45['sf'] == 12][df_p40_d45['transmited_power'] == 2]
# C:\Users\Prosper\AppData\Local\Temp\ipykernel_10816\2930265805.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_p40_d45_sf12_pw20 = df_p40_d45[df_p40_d45['sf'] == 12][df_p40_d45['transmited_power'] == 20]
# ...

# %%
df_send_p10_sf7_pw2 = df_send_p10[df_send_p10['sf'] == 7][df_send_p10['transmited_power'] == 2]
df_send_p10_sf7_pw20 = df_send_p10[df_send_p10['sf'] == 7][df_send_p10['transmited_power'] == 20]
df_send_p10_sf12_pw2 = df_send_p10[df_send_p10['sf'] == 12][df_send_p10['transmited_power'] == 2]
df_send_p10_sf12_pw20 = df_send_p10[df_send_p10['sf'] == 12][df_send_p10['transmited_power'] == 20]

df_send_p20_sf7_pw2 = df_send_p20[df_send_p20['sf'] == 7][df_send_p20['transmited_power'] == 2]
df_send_p20_sf7_pw20 = df_send_p20[df_send_p20['sf'] == 7][df_send_p20['transmited_power'] == 20]
df_send_p20_sf12_pw2 = df_send_p20[df_send_p20['sf'] == 12][df_send_p20['transmited_power'] == 2]
df_send_p20_sf12_pw20 = df_send_p20[df_send_p20['sf'] == 12][df_send_p20['transmited_power'] == 20]

df_send_p30_sf7_pw2 = df_send_p30[df_send_p30['sf'] == 7][df_send_p30['transmited_power'] == 2]
df_send_p30_sf7_pw20 = df_send_p30[df_send_p30['sf'] == 7][df_send_p30['transmited_power'] == 20]
df_send_p30_sf12_pw2 = df_send_p30[df_send_p30['sf'] == 12][df_send_p30['transmited_power'] == 2]
df_send_p30_sf12_pw20 = df_send_p30[df_send_p30['sf'] == 12][df_send_p30['transmited_power'] == 20]

df_send_p40_sf7_pw2 = df_send_p40[df_send_p40['sf'] == 7][df_send_p40['transmited_power'] == 2]
df_send_p40_sf7_pw20 = df_send_p40[df_send_p40['sf'] == 7][df_send_p40['transmited_power'] == 20]
df_send_p40_sf12_pw2 = df_send_p40[df_send_p40['sf'] == 12][df_send_p40['transmited_power'] == 2]
df_send_p40_sf12_pw20 = df_send_p40[df_send_p40['sf'] == 12][df_send_p40['transmited_power'] == 20]

df_send_p50_sf7_pw2 = df_send_p50[df_send_p50['sf'] == 7][df_send_p50['transmited_power'] == 2]
df_send_p50_sf7_pw20 = df_send_p50[df_send_p50['sf'] == 7][df_send_p50['transmited_power'] == 20]
df_send_p50_sf12_pw2 = df_send_p50[df_send_p50['sf'] == 12][df_send_p50['transmited_power'] == 2]
df_send_p50_sf12_pw20 = df_send_p50[df_send_p50['sf'] == 12][df_send_p50['transmited_power'] == 20]

# %%
# Out:
#     id  ambit_humidity  temperature  soil_moisture  transmited_power  sf  \
# 3    4              56           34            0.0                20  12
# 7    8              56           34            0.0                20  12
# 11  12              59           36            0.0                20  12
# 15  16              59           37            0.0                20  12
# 19  20              54           38            0.0                20  12
#
#     rx_timestamp  rssi   snr  sfrx  sftx  tx_trials  tx_power  tx_time_on_air  \
# 3              0     0   0.0     0    12          0        20            1647
# 7              0     0   0.0     0    12          0        20            1647
# 11             0     0   0.0     0    12          0        20            1811
# 15             0     0   0.0     0    12          0        20            1811
# 19     493394935  -125 -11.0     7    12          0        20            1811
#
#     tx_counter  tx_frequency
# ...

# %%
#plt.style.use('seaborn-v0_8-colorblind')
#plt.style.use('seaborn-v0_8-dark-palette')
plt.style.use('seaborn-v0_8-paper')
#plt.style.use('seaborn-v0_8-colorblind')

fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, ncols=1, figsize=(10, 20))

ax1.plot(df_p40_d45_sf7_pw2['rssi'], label='RSSI: sf:7, power:2')
ax1.plot(df_p40_d45_sf7_pw20['rssi'], label='RSSI: sf:7, power:20')
ax1.plot(df_p40_d45_sf12_pw2['rssi'], label='RSSI: sf:12, power:2')
ax1.plot(df_p40_d45_sf12_pw20['rssi'], label='RSSI: sf:12, power:20')

lost_packet(df_send_p10, df_p10_d0, 41, 320)

ax1.set_title('RSSI :: Profondeur: 40, Distance: 45m')
ax1.legend()

ax2.plot(df_p40_d45_sf7_pw2['snr'], label='SNR: sf:7, power:2')
ax2.plot(df_p40_d45_sf7_pw20['snr'], label='SNR: sf:7, power:20')
ax2.plot(df_p40_d45_sf12_pw2['snr'], label='SNR: sf:12, power:2')
ax2.plot(df_p40_d45_sf12_pw20['snr'], label='SNR: sf:12, power:20')

ax2.set_title('SNR :: Profondeur: 40, Distance: 45m')
ax2.legend()

ax3.plot(df_p40_d45obs_sf7_pw2['rssi'], label='RSSI: sf:7, power:2')
ax3.plot(df_p40_d45obs_sf7_pw20['rssi'], label='RSSI: sf:7, power:20')
ax3.plot(df_p40_d45obs_sf12_pw2['rssi'], label='RSSI: sf:12, power:2')
ax3.plot(df_p40_d45obs_sf12_pw20['rssi'], label='RSSI: sf:12, power:20')

ax3.set_title('RSSI :: Profondeur: 40, Distance: 45m OBSTACLE 1 mur')
ax3.legend()

ax4.plot(df_p40_d45obs_sf7_pw2['snr'], label='SNR: sf:7, power:2')
ax4.plot(df_p40_d45obs_sf7_pw20['snr'], label='SNR: sf:7, power:20')
ax4.plot(df_p40_d45obs_sf12_pw2['snr'], label='SNR: sf:12, power:2')
ax4.plot(df_p40_d45obs_sf12_pw20['snr'], label='SNR: sf:12, power:20')

ax4.set_title('SNR :: Profondeur: 40, Distance: 45m OBSTACLE 1 mur')
ax4.legend()

#plt.plot(df_p40_d45obs_sf7_pw20['temperature'], label='Soil moisture')
#plt.plot(df_p40_d45obs_sf12_pw2['temperature'], label='Temperature')

plt.show()

# %%
#plt.style.use('seaborn-v0_8-colorblind')
#plt.style.use('seaborn-v0_8-dark-palette')
plt.style.use('seaborn-v0_8-paper')
#plt.style.use('seaborn-v0_8-colorblind')

fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, ncols=1, figsize=(10, 20))

ax1.plot(df_p40_d45_sf7_pw2['rssi'], label='RSSI: sf:7, power:2')
ax1.plot(df_p40_d45_sf7_pw20['rssi'], label='RSSI: sf:7, power:20')
ax1.plot(df_p40_d45_sf12_pw2['rssi'], label='RSSI: sf:12, power:2')
ax1.plot(df_p40_d45_sf12_pw20['rssi'], label='RSSI: sf:12, power:20')
ax1.plot(df_p40_d45_sf12_pw20['soil_moisture'], label='soil_moisture', linewidth=3)

ax1.set_title('RSSI :: Profondeur: 40, Distance: 45m')
ax1.legend()

ax2.plot(df_p40_d45_sf7_pw2['snr'], label='SNR: sf:7, power:2')
ax2.plot(df_p40_d45_sf7_pw20['snr'], label='SNR: sf:7, power:20')
ax2.plot(df_p40_d45_sf12_pw2['snr'], label='SNR: sf:12, power:2')
ax2.plot(df_p40_d45_sf12_pw20['snr'], label='SNR: sf:12, power:20')
ax2.plot(df_p40_d45_sf12_pw20['soil_moisture'], label='soil_moisture', linewidth=3)

ax2.set_title('SNR :: Profondeur: 40, Distance: 45m')
ax2.legend()

ax3.plot(df_p40_d45obs_sf7_pw2['rssi'], label='RSSI: sf:7, power:2')
ax3.plot(df_p40_d45obs_sf7_pw20['rssi'], label='RSSI: sf:7, power:20')
ax3.plot(df_p40_d45obs_sf12_pw2['rssi'], label='RSSI: sf:12, power:2')
ax3.plot(df_p40_d45obs_sf12_pw20['rssi'], label='RSSI: sf:12, power:20')
ax3.plot(df_p40_d45obs_sf12_pw20['soil_moisture'], label='soil_moisture', linewidth=3)

ax3.set_title('RSSI :: Profondeur: 40, Distance: 45m OBSTACLE 1 mur')
ax3.legend()

ax4.plot(df_p40_d45obs_sf7_pw2['snr'], label='SNR: sf:7, power:2')
ax4.plot(df_p40_d45obs_sf7_pw20['snr'], label='SNR: sf:7, power:20')
ax4.plot(df_p40_d45obs_sf12_pw2['snr'], label='SNR: sf:12, power:2')
ax4.plot(df_p40_d45obs_sf12_pw20['snr'], label='SNR: sf:12, power:20')
ax4.plot(df_p40_d45obs_sf12_pw20['soil_moisture'], label='soil_moisture', linewidth=3)

ax4.set_title('SNR :: Profondeur: 40, Distance: 45m OBSTACLE 1 mur')
ax4.legend()

#plt.plot(df_p40_d45obs_sf7_pw20['temperature'], label='Soil moisture')
#plt.plot(df_p40_d45obs_sf12_pw2['temperature'], label='Temperature')

plt.show()

# %%
#plt.style.use('seaborn-v0_8-colorblind')
#plt.style.use('seaborn-v0_8-dark-palette')
plt.style.use('seaborn-v0_8-paper')
#plt.style.use('seaborn-v0_8-colorblind')

fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, ncols=1, figsize=(10, 20))

ax1.plot(df_p40_d45_sf7_pw2['rssi'], label='RSSI: sf:7, power:2')
ax1.plot(df_p40_d45_sf7_pw20['rssi'], label='RSSI: sf:7, power:20')
ax1.plot(df_p40_d45_sf12_pw2['rssi'], label='RSSI: sf:12, power:2')
ax1.plot(df_p40_d45_sf12_pw20['rssi'], label='RSSI: sf:12, power:20')
ax1.plot(df_p40_d45_sf12_pw20['temperature'], label='temperature', linewidth=2)

ax1.set_title('RSSI :: Profondeur: 40, Distance: 45m')
ax1.legend()

ax2.plot(df_p40_d45_sf7_pw2['snr'], label='SNR: sf:7, power:2')
ax2.plot(df_p40_d45_sf7_pw20['snr'], label='SNR: sf:7, power:20')
ax2.plot(df_p40_d45_sf12_pw2['snr'], label='SNR: sf:12, power:2')
ax2.plot(df_p40_d45_sf12_pw20['snr'], label='SNR: sf:12, power:20')
ax2.plot(df_p40_d45_sf12_pw20['temperature'], label='temperature', linewidth=2)

ax2.set_title('SNR :: Profondeur: 40, Distance: 45m')
ax2.legend()

ax3.plot(df_p40_d45obs_sf7_pw2['rssi'], label='RSSI: sf:7, power:2')
ax3.plot(df_p40_d45obs_sf7_pw20['rssi'], label='RSSI: sf:7, power:20')
ax3.plot(df_p40_d45obs_sf12_pw2['rssi'], label='RSSI: sf:12, power:2')
ax3.plot(df_p40_d45obs_sf12_pw20['rssi'], label='RSSI: sf:12, power:20')
ax3.plot(df_p40_d45obs_sf12_pw20['temperature'], label='temperature', linewidth=2)

ax3.set_title('RSSI :: Profondeur: 40, Distance: 45m OBSTACLE 1 mur')
ax3.legend()

ax4.plot(df_p40_d45obs_sf7_pw2['snr'], label='SNR: sf:7, power:2')
ax4.plot(df_p40_d45obs_sf7_pw20['snr'], label='SNR: sf:7, power:20')
ax4.plot(df_p40_d45obs_sf12_pw2['snr'], label='SNR: sf:12, power:2')
ax4.plot(df_p40_d45obs_sf12_pw20['snr'], label='SNR: sf:12, power:20')
ax4.plot(df_p40_d45obs_sf12_pw20['temperature'], label='temperature', linewidth=2)

ax4.set_title('SNR :: Profondeur: 40, Distance: 45m OBSTACLE 1 mur')
ax4.legend()

#plt.plot(df_p40_d45obs_sf7_pw20['temperature'], label='Soil moisture')
#plt.plot(df_p40_d45obs_sf12_pw2['temperature'], label='Temperature')

plt.show()

# %%
plt.style.use('tableau-colorblind10')

for i in range(len(df)):
    for j in range(len(df[0])):
        plt.plot(range(len(df[i][j][0])), df[i][j][0][df[i][j][0]['sf'] == 12][df[i][j][0]['transmited_power'] == 2]['rssi'], label=df[i][j][1])

        plt.xlabel('Data')
        plt.ylabel('RSSI')
        plt.legend()

        plt.show()
# Out:
# C:\Users\Prosper\AppData\Local\Temp\ipykernel_10816\2139555950.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plt.plot(range(len(df[i][j][0])), df[i][j][0][df[i][j][0]['sf'] == 12][df[i][j][0]['transmited_power'] == 2]['rssi'], label=df[i][j][1])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 5
#       3 for i in range(len(df)):
#       4     for j in range(len(df[0])):
# ----> 5         plt.plot(range(len(df[i][j][0])), df[i][j][0][df[i][j][0]['sf'] == 12][df[i][j][0]['transmited_power'] == 2]['rssi'], label=df[i][j][1])
#       7         plt.xlabel('Data')
#       8         plt.ylabel('RSSI')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
# ...

# %%
df[0][0][0][:100][df[0][0][0]['sf'] == 12][df[0][0][0]['transmited_power'] == 2]
# Out:
# C:\Users\Prosper\AppData\Local\Temp\ipykernel_3812\574491841.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[0][0][0][:100][df[0][0][0]['sf'] == 12][df[0][0][0]['transmited_power'] == 2]
# C:\Users\Prosper\AppData\Local\Temp\ipykernel_3812\574491841.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[0][0][0][:100][df[0][0][0]['sf'] == 12][df[0][0][0]['transmited_power'] == 2]
#                           date   id  ambit_humidity  temperature  \
# 1                         0000   42              72           33
# 5                         0000   46              57           32
# 9                         0000   50              55           32
# 13  2024-06-28 12:02:26.289492   54              54           33
# 17  2024-06-28 12:03:51.308713   58              54           32
# 21                        0000   62              57           32
# 25                        0000   66              56           33
# ...
